# %% [markdown]
# <a href="https://colab.research.google.com/github/rickacharya/Works/blob/main/us_accidents_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Jovian Commit Essentials
# Please retain and execute this cell without modifying the contents for `jovian.commit` to work
# !pip install jovian --upgrade -q
import jovian
jovian.set_project('us-accidents-analysis-6a436')
jovian.set_colab_id('1L4yHpTqnkmR1rQkb22xAAY6o94MbGBPb')
# Out:
#      |████████████████████████████████| 71kB 7.9MB/s
# ...

# %% [markdown]
# # US accidents exploratory data analysis
# TODO: Talk about EDA
#
# TODO: Talk about the dataset
#
# Source: Kaggle
#
# What it contains: Information on accidents in the US
#
# Use: Can be useful to prevent accidents
#
# Note: This dataset does not contain data on New York

# %% [markdown]
# ###Ask and answer questions
# 1.Are there more accidents in warmer or colder areas?
#
# 2.Which are the top 10 cities based on number of accidents?
#
# 3.At what time of the day are most accidents taking place?
#
# 4.Which days of the week has the most accidents?
#
# 5.Which months have the most accidents?

# %% [markdown]
# #Downloading the data

# %%
pip install opendatasets --upgrade --quiet

# %%
import opendatasets as od
url= 'https://www.kaggle.com/sobhanmoosavi/us-accidents'
od.download(url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: saswataacharya
# Your Kaggle Key: ··········
#   7%|▋         | 19.0M/290M [00:00<00:01, 193MB/s]
# ...
# 100%|██████████| 290M/290M [00:01<00:00, 167MB/s]

# %%
data_filename='./us-accidents/US_Accidents_Dec20_Updated.csv'

# %% [markdown]
# #Data Preparation and Cleaning
# 1.Load the file using Pandas
#
# 2.Look at some information about the data and the columns
#
# 3.Fix any missing or incorrect values

# %%
import pandas as pd

# %%
df=pd.read_csv(data_filename)

# %%
df.head(10)
# Out:
#      ID  Severity  ... Nautical_Twilight Astronomical_Twilight
# 0   A-1         2  ...               Day                   Day
# 1   A-2         2  ...               Day                   Day
# 2   A-3         2  ...             Night                 Night
# 3   A-4         2  ...               Day                   Day
# 4   A-5         3  ...               Day                   Day
# 5   A-6         3  ...               Day                   Day
# 6   A-7         4  ...               Day                   Day
# 7   A-8         2  ...             Night                 Night
# 8   A-9         2  ...               Day                   Day
# 9  A-10         2  ...               Day                   Day
#
# [10 rows x 47 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906610 entries, 0 to 2906609
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat  ...  Wind_Speed(mph)  Precipitation(in)
# count  2.906610e+06  2.906610e+06  ...     2.599447e+06       1.605284e+06
# mean   2.288649e+00  3.653027e+01  ...     7.818111e+00       1.119459e-02
# std    5.541618e-01  5.013964e+00  ...     5.431171e+00       1.540812e-01
# min    1.000000e+00  2.455527e+01  ...     0.000000e+00       0.000000e+00
# 25%    2.000000e+00  3.366453e+01  ...     4.600000e+00       0.000000e+00
# 50%    2.000000e+00  3.609977e+01  ...     7.000000e+00       0.000000e+00
# 75%    3.000000e+00  4.037505e+01  ...     1.040000e+01       0.000000e+00
# max    4.000000e+00  4.900220e+01  ...     9.840000e+02       2.400000e+01
#
# [8 rows x 14 columns]

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
nums=df.select_dtypes(include=numerics)
len(nums.columns)
# Out:
# 14

# %%
missing_percentages=df.isnull().sum().sort_values(ascending=False)/len(df)
missing_percentages
# Out:
# Number                   0.650817
# Precipitation(in)        0.447713
# Wind_Chill(F)            0.407299
# Wind_Speed(mph)          0.105677
# End_Lat                  0.097303
# End_Lng                  0.097303
# Visibility(mi)           0.024798
# Weather_Condition        0.024720
# Humidity(%)              0.024520
# Temperature(F)           0.023128
# Wind_Direction           0.021838
# Pressure(in)             0.019579
# Weather_Timestamp        0.016141
# Airport_Code             0.002273
# Timezone                 0.001180
# Zipcode                  0.000383
# Nautical_Twilight        0.000038
# Astronomical_Twilight    0.000038
# Civil_Twilight           0.000038
# Sunrise_Sunset           0.000038
# City                     0.000037
# Amenity                  0.000000
# Severity                 0.000000
# Start_Time               0.000000
# End_Time                 0.000000
# Start_Lat                0.000000
# Start_Lng                0.000000
# ...

# %%
missing_percentages[missing_percentages!=0]
# Out:
# Number                   0.650817
# Precipitation(in)        0.447713
# Wind_Chill(F)            0.407299
# Wind_Speed(mph)          0.105677
# End_Lat                  0.097303
# End_Lng                  0.097303
# Visibility(mi)           0.024798
# Weather_Condition        0.024720
# Humidity(%)              0.024520
# Temperature(F)           0.023128
# Wind_Direction           0.021838
# Pressure(in)             0.019579
# Weather_Timestamp        0.016141
# Airport_Code             0.002273
# Timezone                 0.001180
# Zipcode                  0.000383
# Nautical_Twilight        0.000038
# Astronomical_Twilight    0.000038
# Civil_Twilight           0.000038
# Sunrise_Sunset           0.000038
# City                     0.000037
# dtype: float64

# %%
missing_percentages[missing_percentages!=0].plot(kind='barh')

# %% [markdown]
# #Exploratory Data Analysis and Visualization
# 1.City
#
# 2.Start time
#
# 3.Start Lat,Start Lng
#
# 4.Temperature

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %% [markdown]
# #City

# %%
df.City.nunique()
# Out:
# 11789

# %%
cities_by_accident=df.City.value_counts()
cities_by_accident
# Out:
# Los Angeles    68411
# Houston        68265
# Charlotte      56176
# Miami          49965
# Dallas         48525
#                ...
# South Cairo        1
# Round Top          1
# Mitchells          1
# Coleharbor         1
# Oneill             1
# Name: City, Length: 11789, dtype: int64

# %%
#top 10 accident prone cities
cities_by_accident[:10]
# Out:
# Los Angeles    68411
# Houston        68265
# Charlotte      56176
# Miami          49965
# Dallas         48525
# Austin         38808
# Raleigh        31355
# Atlanta        29244
# Sacramento     28984
# Orlando        28092
# Name: City, dtype: int64

# %%
#check whether the most populated city in US is there in the dataset or not
'New York' in df.City
# Out:
# False

# %%
cities_by_accident[:20].plot(kind='barh')

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
sns.distplot(cities_by_accident)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(cities_by_accident,log_scale=True)

# %%
cities_by_accident[cities_by_accident==1]
# Out:
# Ranburne         1
# Jones Mills      1
# Rivesville       1
# Turners Falls    1
# Keeling          1
#                 ..
# South Cairo      1
# Round Top        1
# Mitchells        1
# Coleharbor       1
# Oneill           1
# Name: City, Length: 1306, dtype: int64

# %%
high_accident_cities=cities_by_accident[cities_by_accident>=1000]
low_accident_cities=cities_by_accident[cities_by_accident<1000]
len(high_accident_cities)
# Out:
# 513

# %%
sns.distplot(high_accident_cities)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(high_accident_cities,log_scale=True)

# %%
len(low_accident_cities)
# Out:
# 11276

# %%
513/11789
# Out:
# 0.04351514123335313

# %% [markdown]
# #Start Time

# %%
df.Start_Time
# Out:
# 0          2019-05-21 08:29:55
# 1          2019-10-07 17:43:09
# 2          2020-12-13 21:53:00
# 3          2018-04-17 16:51:23
# 4          2016-08-31 17:40:49
#                   ...
# 2906605    2018-06-28 08:49:01
# 2906606    2019-01-10 02:01:01
# 2906607    2020-11-23 12:52:00
# 2906608    2019-12-29 22:38:00
# 2906609    2018-03-26 13:35:03
# Name: Start_Time, Length: 2906610, dtype: object

# %%
#parsing date-time
df.Start_Time=pd.to_datetime(df.Start_Time)
df.Start_Time
# Out:
# 0         2019-05-21 08:29:55
# 1         2019-10-07 17:43:09
# 2         2020-12-13 21:53:00
# 3         2018-04-17 16:51:23
# 4         2016-08-31 17:40:49
#                   ...
# 2906605   2018-06-28 08:49:01
# 2906606   2019-01-10 02:01:01
# 2906607   2020-11-23 12:52:00
# 2906608   2019-12-29 22:38:00
# 2906609   2018-03-26 13:35:03
# Name: Start_Time, Length: 2906610, dtype: datetime64[ns]

# %%
#checking hour of the day
df.Start_Time.dt.hour
# Out:
# 0           8
# 1          17
# 2          21
# 3          16
# 4          17
#            ..
# 2906605     8
# 2906606     2
# 2906607    12
# 2906608    22
# 2906609    13
# Name: Start_Time, Length: 2906610, dtype: int64

# %%
#accident trend by hour
sns.distplot(df.Start_Time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 1.Most accidents are taking place between 6 am to 10 am, probably because people are in hurry to get to work
#
# 2.Another peak is there in between 3pm to 6pm, probably because people are coming back from work

# %%
#checking the day of the week
sns.distplot(df.Start_Time.dt.dayofweek,bins=7,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Accidents are mostly evenly distributed on the weekdays and lesser in number in the weekends.

# %% [markdown]
# Is the distribution of accidents by hour the same on weekends as on weekdays?

# %%
sunday_start_time=df.Start_Time[df.Start_Time.dt.dayofweek==6]
sns.distplot(sunday_start_time.dt.hour,kde=False,norm_hist=True,bins=24)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# On sundays, the distribution is more spread out and most accidents took place around the afternoon(10 am to 3 pm), unlike weekdays

# %%
#check for Mondays
monday_start_time=df.Start_Time[df.Start_Time.dt.dayofweek==0]
sns.distplot(monday_start_time.dt.hour,kde=False,norm_hist=True,bins=24)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.Start_Time.dt.month,kde=False,norm_hist=True,bins=12)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#checking if individual years show a similar trend
df.Start_Time.dt.year
df_2019=df[df.Start_Time.dt.year==2019]
sns.distplot(df_2019.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_2016=df[df.Start_Time.dt.year==2016]
sns.distplot(df_2016.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Some data is missing from the 2016 entry

# %%
df_2017=df[df.Start_Time.dt.year==2017]
sns.distplot(df_2017.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #Start Longitude and Latitude

# %%
df.Start_Lat
# Out:
# 0          34.808868
# 1          35.090080
# 2          37.145730
# 3          39.110390
# 4          26.102942
#              ...
# 2906605    29.813824
# 2906606    34.068890
# 2906607    25.702200
# 2906608    40.660140
# 2906609    38.831749
# Name: Start_Lat, Length: 2906610, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -82.269157
# 1          -80.745560
# 2         -121.985052
# 3         -119.773781
# 4          -80.265091
#               ...
# 2906605    -95.399437
# 2906606   -117.342010
# 2906607    -80.335556
# 2906608   -111.952460
# 2906609   -104.748161
# Name: Start_Lng, Length: 2906610, dtype: float64

# %%
sample_df=df.sample(int(len(df)*0.1))

sns.scatterplot(x=sample_df.Start_Lng,y=sample_df.Start_Lat,size=0.001)

# %%
import folium

# %%
#using 0.1% of the dataset to map fast
sample_df1=df.sample(int((0.001*len(df))))
list_of_locations=list(zip(list(sample_df1.Start_Lat),list(sample_df1.Start_Lng)))

# %%
from folium import plugins
from folium.plugins import HeatMap

# %%
HeatMap(list_of_locations).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# #Temperature

# %%
df['Temperature(F)']
# Out:
# 0          76.0
# 1          76.0
# 2          51.0
# 3          53.6
# 4          84.2
#            ...
# 2906605    84.2
# 2906606    46.9
# 2906607    76.0
# 2906608    27.0
# 2906609    51.1
# Name: Temperature(F), Length: 2906610, dtype: float64

# %%
sample_df2=df.sample(int(0.01*len(df)))
sns.distplot(sample_df2['Temperature(F)'],kde=False,bins=25)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#check for individual years
df_2019['Temperature(F)']
# Out:
# 0          76.0
# 1          76.0
# 6          28.0
# 7          55.0
# 9          57.0
#            ...
# 2906587    73.0
# 2906588    21.9
# 2906600    77.0
# 2906606    46.9
# 2906608    27.0
# Name: Temperature(F), Length: 617712, dtype: float64

# %%
sample_df_2019=df.sample(int(0.01*len(df_2019)))
sns.distplot(sample_df_2019['Temperature(F)'],kde=False,bins=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# It has been found that most accidents took place in the temperature range of
# 60°F to 80°F

# %% [markdown]
# #Summary and Conclusion
# Insights:
#
# 1.No data on New York,which is the most populated city in the US is available.
#
# 2.Less than 5% of the cities have more than 1000 accidents per year.
#
# 3.Over 1300 cities have reported only one accident.
#
# 4.Number of accidents per city decreases exponentially.
#
# 5.Both the coasts have high number of accidents.

# %%
jovian.commit()
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Please enter your API key ( from https://jovian.ai/ ):
# API KEY: ··········
# [jovian] Uploading colab notebook to Jovian...
# Committed successfully! https://jovian.ai/saswataacharya-bce20/us-accidents-analysis-6a436
# 'https://jovian.ai/saswataacharya-bce20/us-accidents-analysis-6a436'
